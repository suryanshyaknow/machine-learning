# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve
from pandas_profiling import ProfileReport

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
ProfileReport(df).to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
fig = plt.figure()
fig.set_size_inches(12,12)
sns.heatmap(df.corr(), cmap = 'YlGnBu', annot=True)
# Out:
# <AxesSubplot:>

# %%
X = df.drop(columns=['quality'])
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
Y = df[['quality']]
Y.head()
# Out:
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=150)

# %%
x_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 139             7.8              0.56         0.19             2.0      0.081
# 876             7.1              0.47         0.00             2.2      0.067
# 363            12.5              0.46         0.63             2.0      0.071
# 1328            6.5              0.52         0.11             1.8      0.073
# 138             7.8              0.56         0.19             2.1      0.081
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 139                  17.0                 108.0  0.99620  3.32       0.54
# 876                   7.0                  14.0  0.99517  3.40       0.58
# 363                   6.0                  15.0  0.99880  2.99       0.87
# 1328                 13.0                  38.0  0.99550  3.34       0.52
# 138                  15.0                 105.0  0.99620  3.33       0.54
#
#       alcohol
# 139       9.5
# 876      10.9
# 363      10.2
# 1328      9.3
# 138       9.5

# %%
y_train.head()
# Out:
#       quality
# 139         5
# 876         4
# 363         5
# 1328        5
# 138         5

# %%
mod = DecisionTreeClassifier()
mod.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# on the training dataset
mod.score(x_train, y_train) # kinda overfitting on the training datset
# Out:
# 1.0

# %%
# on the test dataset
mod.score(x_test, y_test)
# Out:
# 0.634375

# %% [markdown]
# ### trying w removing the duplicate records:

# %%
df1 = df.drop_duplicates()
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1359 rows x 12 columns]

# %%
X1 = df1.drop(columns=['quality'])
Y1 = df1[['quality']]

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(X1, Y1, test_size=0.4, random_state=500)
mod1 = DecisionTreeClassifier()
mod1.fit(x1_train, y1_train)
# Out:
# DecisionTreeClassifier()

# %%
mod1.score(x1_test, y1_test)

# the accuracy decreased even more after dropping the duplicate records
# Out:
# 0.49264705882352944

# %% [markdown]
# ### Implementing the criteria = `entropy`

# %%
mod2 = DecisionTreeClassifier(criterion='entropy')
mod2.fit(x1_train, y1_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
mod2.score(x1_test, y1_test)

# increased somewhat
# Out:
# 0.5110294117647058

# %%
dotFile = open('dtree_meta.dot', 'w')
tree.export_graphviz(mod2, dotFile, feature_names=X1.columns)

# %% [markdown]
# ## # Visualizing the Decision Tree:

# %%
from sklearn import tree
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(20, 20))
tree.plot_tree(mod2, filled=True)
# Out:
# [Text(0.44322849548969073, 0.975, 'X[10] <= 10.35\nentropy = 1.718\nsamples = 815\nvalue = [7, 32, 359, 315, 94, 8]'),
#  Text(0.16504913015463918, 0.925, 'X[1] <= 0.335\nentropy = 1.338\nsamples = 446\nvalue = [6, 16, 281, 132, 10, 1]'),
#  Text(0.03350515463917526, 0.875, 'X[4] <= 0.097\nentropy = 1.498\nsamples = 42\nvalue = [0, 1, 7, 27, 6, 1]'),
#  Text(0.020618556701030927, 0.825, 'X[9] <= 0.51\nentropy = 1.297\nsamples = 37\nvalue = [0, 1, 3, 27, 5, 1]'),
#  Text(0.010309278350515464, 0.775, 'X[1] <= 0.275\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.005154639175257732, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.015463917525773196, 0.725, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.030927835051546393, 0.775, 'X[3] <= 14.45\nentropy = 0.97\nsamples = 34\nvalue = [0, 0, 1, 27, 5, 1]'),
#  Text(0.02577319587628866, 0.725, 'X[4] <= 0.076\nentropy = 0.802\nsamples = 33\nvalue = [0, 0, 0, 27, 5, 1]'),
#  Text(0.020618556701030927, 0.675, 'X[1] <= 0.325\nentropy = 1.105\nsamples = 19\nvalue = [0, 0, 0, 13, 5, 1]'),
#  Text(0.015463917525773196, 0.625, 'X[8] <= 3.095\nentropy = 0.852\nsamples = 18\nvalue = [0, 0, 0, 13, 5, 0]'),
#  Text(0.010309278350515464, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.020618556701030927, 0.575, 'X[3] <= 1.45\nentropy = 0.696\nsamples = 16\nvalue = [0, 0, 0, 13, 3, 0]'),
#  Text(0.010309278350515464, 0.525, 'X[9] <= 0.73\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.005154639175257732, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.015463917525773196, 0.475, 'X[2] <= 0.465\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.010309278350515464, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.020618556701030927, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.030927835051546393, 0.525, 'X[5] <= 35.0\nentropy = 0.391\nsamples = 13\nvalue = [0, 0, 0, 12, 1, 0]'),
#  Text(0.02577319587628866, 0.475, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.03608247422680412, 0.475, 'X[5] <= 48.5\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.030927835051546393, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.041237113402061855, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.02577319587628866, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.030927835051546393, 0.675, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.03608247422680412, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.04639175257731959, 0.825, 'X[4] <= 0.236\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 4, 0, 1, 0]'),
#  Text(0.041237113402061855, 0.775, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.05154639175257732, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2965931056701031, 0.875, 'X[6] <= 52.5\nentropy = 1.218\nsamples = 404\nvalue = [6, 15, 274, 105, 4, 0]'),
#  Text(0.2033666237113402, 0.825, 'X[1] <= 0.572\nentropy = 1.485\nsamples = 219\nvalue = [6, 13, 123, 73, 4, 0]'),
#  Text(0.11275773195876289, 0.775, 'X[9] <= 0.585\nentropy = 1.356\nsamples = 103\nvalue = [0, 4, 46, 50, 3, 0]'),
#  Text(0.08891752577319588, 0.725, 'X[9] <= 0.475\nentropy = 1.318\nsamples = 40\nvalue = [0, 4, 23, 13, 0, 0]'),
#  Text(0.08376288659793814, 0.675, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.09407216494845361, 0.675, 'X[9] <= 0.565\nentropy = 1.425\nsamples = 31\nvalue = [0, 4, 14, 13, 0, 0]'),
#  Text(0.07989690721649484, 0.625, 'X[3] <= 1.95\nentropy = 1.382\nsamples = 24\nvalue = [0, 3, 8, 13, 0, 0]'),
#  Text(0.06701030927835051, 0.575, 'X[10] <= 9.75\nentropy = 1.281\nsamples = 12\nvalue = [0, 1, 7, 4, 0, 0]'),
#  Text(0.061855670103092786, 0.525, 'X[5] <= 16.5\nentropy = 0.986\nsamples = 9\nvalue = [0, 1, 7, 1, 0, 0]'),
#  Text(0.05670103092783505, 0.475, 'X[4] <= 0.089\nentropy = 0.544\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.05154639175257732, 0.425, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.061855670103092786, 0.425, 'X[8] <= 3.27\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.05670103092783505, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06701030927835051, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.06701030927835051, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.07216494845360824, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.09278350515463918, 0.575, 'X[4] <= 0.069\nentropy = 1.041\nsamples = 12\nvalue = [0, 2, 1, 9, 0, 0]'),
#  Text(0.08247422680412371, 0.525, 'X[7] <= 0.996\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.07731958762886598, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.08762886597938144, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.10309278350515463, 0.525, 'X[4] <= 0.102\nentropy = 0.469\nsamples = 10\nvalue = [0, 1, 0, 9, 0, 0]'),
#  Text(0.0979381443298969, 0.475, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.10824742268041238, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.10824742268041238, 0.625, 'X[3] <= 4.0\nentropy = 0.592\nsamples = 7\nvalue = [0, 1, 6, 0, 0, 0]'),
#  Text(0.10309278350515463, 0.575, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.1134020618556701, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.13659793814432988, 0.725, 'X[7] <= 0.996\nentropy = 1.191\nsamples = 63\nvalue = [0, 0, 23, 37, 3, 0]'),
#  Text(0.12371134020618557, 0.675, 'X[1] <= 0.425\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(0.11855670103092783, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.12886597938144329, 0.625, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.14948453608247422, 0.675, 'X[6] <= 43.5\nentropy = 1.165\nsamples = 57\nvalue = [0, 0, 23, 32, 2, 0]'),
#  Text(0.13917525773195877, 0.625, 'X[4] <= 0.168\nentropy = 0.998\nsamples = 42\nvalue = [0, 0, 20, 22, 0, 0]'),
#  Text(0.13402061855670103, 0.575, 'X[4] <= 0.094\nentropy = 0.991\nsamples = 36\nvalue = [0, 0, 20, 16, 0, 0]'),
#  Text(0.12886597938144329, 0.525, 'X[6] <= 41.0\nentropy = 0.985\nsamples = 28\nvalue = [0, 0, 12, 16, 0, 0]'),
#  Text(0.12371134020618557, 0.475, 'X[7] <= 0.997\nentropy = 0.943\nsamples = 25\nvalue = [0, 0, 9, 16, 0, 0]'),
#  Text(0.1134020618556701, 0.425, 'X[2] <= 0.01\nentropy = 0.863\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.10824742268041238, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.11855670103092783, 0.375, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.13402061855670103, 0.425, 'X[9] <= 0.635\nentropy = 0.764\nsamples = 18\nvalue = [0, 0, 4, 14, 0, 0]'),
#  Text(0.12886597938144329, 0.375, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.13917525773195877, 0.375, 'X[9] <= 0.645\nentropy = 0.918\nsamples = 12\nvalue = [0, 0, 4, 8, 0, 0]'),
#  Text(0.13402061855670103, 0.325, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.14432989690721648, 0.325, 'X[3] <= 2.15\nentropy = 0.722\nsamples = 10\nvalue = [0, 0, 2, 8, 0, 0]'),
#  Text(0.13917525773195877, 0.275, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.14948453608247422, 0.275, 'X[3] <= 2.35\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.14432989690721648, 0.225, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.15463917525773196, 0.225, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.13402061855670103, 0.475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.13917525773195877, 0.525, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.14432989690721648, 0.575, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.15979381443298968, 0.625, 'X[2] <= 0.325\nentropy = 1.242\nsamples = 15\nvalue = [0, 0, 3, 10, 2, 0]'),
#  Text(0.15463917525773196, 0.575, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.16494845360824742, 0.575, 'X[10] <= 9.55\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 3, 0, 2, 0]'),
#  Text(0.15979381443298968, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.17010309278350516, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.29397551546391754, 0.775, 'X[4] <= 0.193\nentropy = 1.422\nsamples = 116\nvalue = [6, 9, 77, 23, 1, 0]'),
#  Text(0.26707474226804123, 0.725, 'X[3] <= 2.15\nentropy = 1.358\nsamples = 113\nvalue = [4, 9, 77, 22, 1, 0]'),
#  Text(0.22873711340206185, 0.675, 'X[1] <= 0.712\nentropy = 1.524\nsamples = 68\nvalue = [2, 9, 42, 14, 1, 0]'),
#  Text(0.19974226804123713, 0.625, 'X[7] <= 0.996\nentropy = 1.415\nsamples = 49\nvalue = [0, 5, 29, 14, 1, 0]'),
#  Text(0.18556701030927836, 0.575, 'X[8] <= 3.615\nentropy = 0.439\nsamples = 11\nvalue = [0, 1, 10, 0, 0, 0]'),
#  Text(0.18041237113402062, 0.525, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.19072164948453607, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.21391752577319587, 0.575, 'X[8] <= 3.355\nentropy = 1.511\nsamples = 38\nvalue = [0, 4, 19, 14, 1, 0]'),
#  Text(0.20103092783505155, 0.525, 'X[3] <= 2.05\nentropy = 1.493\nsamples = 14\nvalue = [0, 4, 3, 7, 0, 0]'),
#  Text(0.1958762886597938, 0.475, 'X[9] <= 0.865\nentropy = 1.241\nsamples = 11\nvalue = [0, 1, 3, 7, 0, 0]'),
#  Text(0.19072164948453607, 0.425, 'X[0] <= 8.65\nentropy = 0.881\nsamples = 10\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.18556701030927836, 0.375, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.1958762886597938, 0.375, 'X[4] <= 0.081\nentropy = 1.0\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.19072164948453607, 0.325, 'X[9] <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.18556701030927836, 0.275, 'X[4] <= 0.054\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.18041237113402062, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19072164948453607, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1958762886597938, 0.275, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.20103092783505155, 0.325, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.20103092783505155, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.20618556701030927, 0.475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.2268041237113402, 0.525, 'X[9] <= 0.575\nentropy = 1.099\nsamples = 24\nvalue = [0, 0, 16, 7, 1, 0]'),
#  Text(0.21649484536082475, 0.475, 'X[1] <= 0.6\nentropy = 0.544\nsamples = 8\nvalue = [0, 0, 7, 0, 1, 0]'),
#  Text(0.211340206185567, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.22164948453608246, 0.425, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.23711340206185566, 0.475, 'X[0] <= 6.95\nentropy = 0.989\nsamples = 16\nvalue = [0, 0, 9, 7, 0, 0]'),
#  Text(0.23195876288659795, 0.425, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.2422680412371134, 0.425, 'X[7] <= 0.997\nentropy = 0.881\nsamples = 10\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.23711340206185566, 0.375, 'X[2] <= 0.03\nentropy = 0.544\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.23195876288659795, 0.325, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.2422680412371134, 0.325, 'X[7] <= 0.997\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.23711340206185566, 0.275, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.24742268041237114, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.24742268041237114, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.25773195876288657, 0.625, 'X[9] <= 0.545\nentropy = 1.19\nsamples = 19\nvalue = [2, 4, 13, 0, 0, 0]'),
#  Text(0.24742268041237114, 0.575, 'X[3] <= 1.65\nentropy = 0.946\nsamples = 11\nvalue = [0, 4, 7, 0, 0, 0]'),
#  Text(0.2422680412371134, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.25257731958762886, 0.525, 'X[0] <= 7.8\nentropy = 0.764\nsamples = 9\nvalue = [0, 2, 7, 0, 0, 0]'),
#  Text(0.24742268041237114, 0.475, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.25773195876288657, 0.475, 'X[3] <= 1.75\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.25257731958762886, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.26288659793814434, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.26804123711340205, 0.575, 'X[8] <= 3.3\nentropy = 0.811\nsamples = 8\nvalue = [2, 0, 6, 0, 0, 0]'),
#  Text(0.26288659793814434, 0.525, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.27319587628865977, 0.525, 'X[6] <= 50.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 1, 0, 0, 0]'),
#  Text(0.26804123711340205, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.27835051546391754, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.30541237113402064, 0.675, 'X[7] <= 0.998\nentropy = 0.925\nsamples = 45\nvalue = [2, 0, 35, 8, 0, 0]'),
#  Text(0.28350515463917525, 0.625, 'X[1] <= 0.95\nentropy = 0.391\nsamples = 26\nvalue = [0, 0, 24, 2, 0, 0]'),
#  Text(0.27835051546391754, 0.575, 'entropy = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0, 0, 0]'),
#  Text(0.28865979381443296, 0.575, 'X[2] <= 0.025\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.28350515463917525, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.29381443298969073, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.327319587628866, 0.625, 'X[9] <= 0.695\nentropy = 1.324\nsamples = 19\nvalue = [2, 0, 11, 6, 0, 0]'),
#  Text(0.31443298969072164, 0.575, 'X[4] <= 0.083\nentropy = 1.149\nsamples = 14\nvalue = [2, 0, 10, 2, 0, 0]'),
#  Text(0.30412371134020616, 0.525, 'X[8] <= 3.205\nentropy = 0.971\nsamples = 5\nvalue = [2, 0, 3, 0, 0, 0]'),
#  Text(0.29896907216494845, 0.475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.30927835051546393, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.3247422680412371, 0.525, 'X[7] <= 0.999\nentropy = 0.764\nsamples = 9\nvalue = [0, 0, 7, 2, 0, 0]'),
#  Text(0.31958762886597936, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.32989690721649484, 0.475, 'X[4] <= 0.094\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.3247422680412371, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.33505154639175255, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3402061855670103, 0.575, 'X[4] <= 0.091\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.33505154639175255, 0.525, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.34536082474226804, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.32087628865979384, 0.725, 'X[3] <= 2.3\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 0, 1, 0, 0]'),
#  Text(0.31572164948453607, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.32603092783505155, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.389819587628866, 0.825, 'X[6] <= 114.5\nentropy = 0.748\nsamples = 185\nvalue = [0, 2, 151, 32, 0, 0]'),
#  Text(0.38466494845360827, 0.775, 'X[8] <= 2.92\nentropy = 0.839\nsamples = 152\nvalue = [0, 2, 118, 32, 0, 0]'),
#  Text(0.3634020618556701, 0.725, 'X[1] <= 0.64\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.3582474226804124, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.36855670103092786, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4059278350515464, 0.725, 'X[4] <= 0.097\nentropy = 0.791\nsamples = 150\nvalue = [0, 1, 118, 31, 0, 0]'),
#  Text(0.3788659793814433, 0.675, 'X[2] <= 0.115\nentropy = 0.895\nsamples = 112\nvalue = [0, 1, 82, 29, 0, 0]'),
#  Text(0.3556701030927835, 0.625, 'X[8] <= 3.545\nentropy = 0.258\nsamples = 23\nvalue = [0, 0, 22, 1, 0, 0]'),
#  Text(0.35051546391752575, 0.575, 'entropy = 0.0\nsamples = 21\nvalue = [0, 0, 21, 0, 0, 0]'),
#  Text(0.36082474226804123, 0.575, 'X[10] <= 9.8\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3556701030927835, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.36597938144329895, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4020618556701031, 0.625, 'X[4] <= 0.09\nentropy = 0.981\nsamples = 89\nvalue = [0, 1, 60, 28, 0, 0]'),
#  Text(0.38144329896907214, 0.575, 'X[4] <= 0.083\nentropy = 0.833\nsamples = 72\nvalue = [0, 0, 53, 19, 0, 0]'),
#  Text(0.37628865979381443, 0.525, 'X[0] <= 8.25\nentropy = 0.907\nsamples = 59\nvalue = [0, 0, 40, 19, 0, 0]'),
#  Text(0.36082474226804123, 0.475, 'X[10] <= 9.225\nentropy = 0.976\nsamples = 44\nvalue = [0, 0, 26, 18, 0, 0]'),
#  Text(0.3556701030927835, 0.425, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.36597938144329895, 0.425, 'X[10] <= 10.05\nentropy = 0.998\nsamples = 38\nvalue = [0, 0, 20, 18, 0, 0]'),
#  Text(0.36082474226804123, 0.375, 'X[0] <= 7.85\nentropy = 0.994\nsamples = 33\nvalue = [0, 0, 15, 18, 0, 0]'),
#  Text(0.3556701030927835, 0.325, 'X[3] <= 2.45\nentropy = 0.983\nsamples = 26\nvalue = [0, 0, 15, 11, 0, 0]'),
#  Text(0.35051546391752575, 0.275, 'X[9] <= 0.535\nentropy = 0.932\nsamples = 23\nvalue = [0, 0, 15, 8, 0, 0]'),
#  Text(0.34536082474226804, 0.225, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.3556701030927835, 0.225, 'X[4] <= 0.078\nentropy = 0.998\nsamples = 17\nvalue = [0, 0, 9, 8, 0, 0]'),
#  Text(0.34536082474226804, 0.175, 'X[8] <= 3.27\nentropy = 0.592\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.3402061855670103, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.35051546391752575, 0.125, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.36597938144329895, 0.175, 'X[0] <= 7.45\nentropy = 0.881\nsamples = 10\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.36082474226804123, 0.125, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.3711340206185567, 0.125, 'X[1] <= 0.375\nentropy = 1.0\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.36597938144329895, 0.075, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.37628865979381443, 0.075, 'X[5] <= 26.5\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.3711340206185567, 0.025, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.38144329896907214, 0.025, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.36082474226804123, 0.275, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.36597938144329895, 0.325, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.3711340206185567, 0.375, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.3917525773195876, 0.475, 'X[8] <= 3.115\nentropy = 0.353\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]'),
#  Text(0.3865979381443299, 0.425, 'X[4] <= 0.078\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.38144329896907214, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3917525773195876, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.39690721649484534, 0.425, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.3865979381443299, 0.525, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.422680412371134, 0.575, 'X[9] <= 0.615\nentropy = 1.253\nsamples = 17\nvalue = [0, 1, 7, 9, 0, 0]'),
#  Text(0.4175257731958763, 0.525, 'X[3] <= 3.5\nentropy = 1.157\nsamples = 10\nvalue = [0, 1, 7, 2, 0, 0]'),
#  Text(0.41237113402061853, 0.475, 'X[6] <= 80.5\nentropy = 0.544\nsamples = 8\nvalue = [0, 1, 7, 0, 0, 0]'),
#  Text(0.4072164948453608, 0.425, 'X[10] <= 9.65\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.4020618556701031, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.41237113402061853, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4175257731958763, 0.425, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.422680412371134, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.42783505154639173, 0.525, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.4329896907216495, 0.675, 'X[7] <= 0.996\nentropy = 0.297\nsamples = 38\nvalue = [0, 0, 36, 2, 0, 0]'),
#  Text(0.42783505154639173, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4381443298969072, 0.625, 'X[3] <= 11.75\nentropy = 0.179\nsamples = 37\nvalue = [0, 0, 36, 1, 0, 0]'),
#  Text(0.4329896907216495, 0.575, 'entropy = 0.0\nsamples = 36\nvalue = [0, 0, 36, 0, 0, 0]'),
#  Text(0.44329896907216493, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3949742268041237, 0.775, 'entropy = 0.0\nsamples = 33\nvalue = [0, 0, 33, 0, 0, 0]'),
#  Text(0.7214078608247423, 0.925, 'X[9] <= 0.625\nentropy = 1.79\nsamples = 369\nvalue = [1, 16, 78, 183, 84, 7]'),
#  Text(0.6056701030927835, 0.875, 'X[1] <= 1.015\nentropy = 1.682\nsamples = 160\nvalue = [1, 15, 50, 81, 13, 0]'),
#  Text(0.5670103092783505, 0.825, 'X[3] <= 3.85\nentropy = 1.586\nsamples = 154\nvalue = [0, 11, 49, 81, 13, 0]'),
#  Text(0.5180412371134021, 0.775, 'X[1] <= 0.385\nentropy = 1.446\nsamples = 138\nvalue = [0, 6, 45, 78, 9, 0]'),
#  Text(0.4793814432989691, 0.725, 'X[9] <= 0.585\nentropy = 1.27\nsamples = 35\nvalue = [0, 0, 6, 23, 6, 0]'),
#  Text(0.4690721649484536, 0.675, 'X[7] <= 0.994\nentropy = 0.764\nsamples = 25\nvalue = [0, 0, 1, 21, 3, 0]'),
#  Text(0.4639175257731959, 0.625, 'X[6] <= 14.5\nentropy = 1.241\nsamples = 11\nvalue = [0, 0, 1, 7, 3, 0]'),
#  Text(0.4536082474226804, 0.575, 'X[4] <= 0.064\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 0, 2, 3, 0]'),
#  Text(0.4484536082474227, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4587628865979381, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.4742268041237113, 0.575, 'X[10] <= 11.7\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.4690721649484536, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4793814432989691, 0.525, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.4742268041237113, 0.625, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.4896907216494845, 0.675, 'X[7] <= 0.994\nentropy = 1.485\nsamples = 10\nvalue = [0, 0, 5, 2, 3, 0]'),
#  Text(0.4845360824742268, 0.625, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.4948453608247423, 0.625, 'X[10] <= 10.75\nentropy = 0.863\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.4896907216494845, 0.575, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.5, 0.575, 'X[3] <= 2.325\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.4948453608247423, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5051546391752577, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5567010309278351, 0.725, 'X[5] <= 8.5\nentropy = 1.401\nsamples = 103\nvalue = [0, 6, 39, 55, 3, 0]'),
#  Text(0.5360824742268041, 0.675, 'X[4] <= 0.087\nentropy = 1.426\nsamples = 36\nvalue = [0, 5, 18, 13, 0, 0]'),
#  Text(0.5257731958762887, 0.625, 'X[4] <= 0.08\nentropy = 1.44\nsamples = 29\nvalue = [0, 4, 12, 13, 0, 0]'),
#  Text(0.520618556701031, 0.575, 'X[1] <= 0.722\nentropy = 1.435\nsamples = 22\nvalue = [0, 4, 12, 6, 0, 0]'),
#  Text(0.5154639175257731, 0.525, 'X[9] <= 0.615\nentropy = 1.371\nsamples = 20\nvalue = [0, 4, 12, 4, 0, 0]'),
#  Text(0.5103092783505154, 0.475, 'X[3] <= 2.55\nentropy = 1.224\nsamples = 18\nvalue = [0, 4, 12, 2, 0, 0]'),
#  Text(0.5051546391752577, 0.425, 'X[0] <= 7.0\nentropy = 1.459\nsamples = 12\nvalue = [0, 4, 6, 2, 0, 0]'),
#  Text(0.4948453608247423, 0.375, 'X[7] <= 0.992\nentropy = 1.061\nsamples = 8\nvalue = [0, 1, 6, 1, 0, 0]'),
#  Text(0.4896907216494845, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5, 0.325, 'X[0] <= 5.1\nentropy = 0.592\nsamples = 7\nvalue = [0, 1, 6, 0, 0, 0]'),
#  Text(0.4948453608247423, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5051546391752577, 0.275, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.5154639175257731, 0.375, 'X[5] <= 7.5\nentropy = 0.811\nsamples = 4\nvalue = [0, 3, 0, 1, 0, 0]'),
#  Text(0.5103092783505154, 0.325, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.520618556701031, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5154639175257731, 0.425, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.520618556701031, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5257731958762887, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5309278350515464, 0.575, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.5463917525773195, 0.625, 'X[1] <= 0.395\nentropy = 0.592\nsamples = 7\nvalue = [0, 1, 6, 0, 0, 0]'),
#  Text(0.5412371134020618, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5515463917525774, 0.575, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.5773195876288659, 0.675, 'X[6] <= 18.5\nentropy = 1.238\nsamples = 67\nvalue = [0, 1, 21, 42, 3, 0]'),
#  Text(0.5670103092783505, 0.625, 'X[8] <= 3.39\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.5618556701030928, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.5721649484536082, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5876288659793815, 0.625, 'X[8] <= 3.575\nentropy = 1.134\nsamples = 63\nvalue = [0, 1, 21, 40, 1, 0]'),
#  Text(0.5824742268041238, 0.575, 'X[7] <= 0.998\nentropy = 1.203\nsamples = 54\nvalue = [0, 1, 21, 31, 1, 0]'),
#  Text(0.5773195876288659, 0.525, 'X[6] <= 43.5\nentropy = 1.245\nsamples = 48\nvalue = [0, 1, 21, 25, 1, 0]'),
#  Text(0.5567010309278351, 0.475, 'X[9] <= 0.615\nentropy = 1.091\nsamples = 29\nvalue = [0, 0, 9, 19, 1, 0]'),
#  Text(0.5515463917525774, 0.425, 'X[4] <= 0.054\nentropy = 0.906\nsamples = 28\nvalue = [0, 0, 9, 19, 0, 0]'),
#  Text(0.5463917525773195, 0.375, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5567010309278351, 0.375, 'X[3] <= 2.25\nentropy = 0.795\nsamples = 25\nvalue = [0, 0, 6, 19, 0, 0]'),
#  Text(0.5515463917525774, 0.325, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.5618556701030928, 0.325, 'X[9] <= 0.565\nentropy = 0.996\nsamples = 13\nvalue = [0, 0, 6, 7, 0, 0]'),
#  Text(0.5515463917525774, 0.275, 'X[1] <= 0.618\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.5463917525773195, 0.225, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.5567010309278351, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5721649484536082, 0.275, 'X[4] <= 0.069\nentropy = 0.592\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.5670103092783505, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5773195876288659, 0.225, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.5618556701030928, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5979381443298969, 0.475, 'X[7] <= 0.995\nentropy = 1.167\nsamples = 19\nvalue = [0, 1, 12, 6, 0, 0]'),
#  Text(0.5876288659793815, 0.425, 'X[8] <= 3.335\nentropy = 1.0\nsamples = 12\nvalue = [0, 0, 6, 6, 0, 0]'),
#  Text(0.5824742268041238, 0.375, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5927835051546392, 0.375, 'X[5] <= 23.5\nentropy = 0.918\nsamples = 9\nvalue = [0, 0, 6, 3, 0, 0]'),
#  Text(0.5876288659793815, 0.325, 'X[0] <= 6.35\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.5824742268041238, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5927835051546392, 0.275, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5979381443298969, 0.325, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.6082474226804123, 0.425, 'X[2] <= 0.355\nentropy = 0.592\nsamples = 7\nvalue = [0, 1, 6, 0, 0, 0]'),
#  Text(0.6030927835051546, 0.375, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.6134020618556701, 0.375, 'X[7] <= 0.998\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.6082474226804123, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6185567010309279, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5876288659793815, 0.525, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.5927835051546392, 0.575, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.615979381443299, 0.775, 'X[4] <= 0.069\nentropy = 1.977\nsamples = 16\nvalue = [0, 5, 4, 3, 4, 0]'),
#  Text(0.5979381443298969, 0.725, 'X[8] <= 3.25\nentropy = 0.985\nsamples = 7\nvalue = [0, 4, 0, 0, 3, 0]'),
#  Text(0.5927835051546392, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.6030927835051546, 0.675, 'X[7] <= 0.996\nentropy = 0.722\nsamples = 5\nvalue = [0, 4, 0, 0, 1, 0]'),
#  Text(0.5979381443298969, 0.625, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.6082474226804123, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.634020618556701, 0.725, 'X[3] <= 4.5\nentropy = 1.753\nsamples = 9\nvalue = [0, 1, 4, 3, 1, 0]'),
#  Text(0.6237113402061856, 0.675, 'X[3] <= 4.2\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.6185567010309279, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6288659793814433, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6443298969072165, 0.675, 'X[10] <= 10.9\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.6391752577319587, 0.625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6494845360824743, 0.625, 'X[3] <= 4.7\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.6443298969072165, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.654639175257732, 0.575, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.6443298969072165, 0.825, 'X[1] <= 1.147\nentropy = 1.252\nsamples = 6\nvalue = [1, 4, 1, 0, 0, 0]'),
#  Text(0.6391752577319587, 0.775, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.6494845360824743, 0.775, 'X[0] <= 7.7\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.6443298969072165, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.654639175257732, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.837145618556701, 0.875, 'X[10] <= 11.55\nentropy = 1.624\nsamples = 209\nvalue = [0, 1, 28, 102, 71, 7]'),
#  Text(0.71875, 0.825, 'X[0] <= 6.95\nentropy = 1.452\nsamples = 121\nvalue = [0, 1, 23, 70, 27, 0]'),
#  Text(0.6701030927835051, 0.775, 'X[4] <= 0.119\nentropy = 0.549\nsamples = 21\nvalue = [0, 1, 0, 19, 1, 0]'),
#  Text(0.6649484536082474, 0.725, 'entropy = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]'),
#  Text(0.6752577319587629, 0.725, 'X[6] <= 32.0\nentropy = 1.585\nsamples = 3\nvalue = [0, 1, 0, 1, 1, 0]'),
#  Text(0.6701030927835051, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6804123711340206, 0.675, 'X[6] <= 34.5\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.6752577319587629, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6855670103092784, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7673969072164949, 0.775, 'X[1] <= 0.375\nentropy = 1.488\nsamples = 100\nvalue = [0, 0, 23, 51, 26, 0]'),
#  Text(0.7152061855670103, 0.725, 'X[8] <= 3.25\nentropy = 1.539\nsamples = 40\nvalue = [0, 0, 10, 12, 18, 0]'),
#  Text(0.7010309278350515, 0.675, 'X[0] <= 10.45\nentropy = 0.896\nsamples = 16\nvalue = [0, 0, 0, 5, 11, 0]'),
#  Text(0.6958762886597938, 0.625, 'X[1] <= 0.34\nentropy = 0.991\nsamples = 9\nvalue = [0, 0, 0, 5, 4, 0]'),
#  Text(0.6907216494845361, 0.575, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7010309278350515, 0.575, 'X[9] <= 0.7\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.6958762886597938, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7061855670103093, 0.525, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.7061855670103093, 0.625, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.729381443298969, 0.675, 'X[9] <= 0.715\nentropy = 1.563\nsamples = 24\nvalue = [0, 0, 10, 7, 7, 0]'),
#  Text(0.7242268041237113, 0.625, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.7345360824742269, 0.625, 'X[0] <= 8.05\nentropy = 1.568\nsamples = 19\nvalue = [0, 0, 5, 7, 7, 0]'),
#  Text(0.7216494845360825, 0.575, 'X[6] <= 58.0\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 3, 0, 2, 0]'),
#  Text(0.7164948453608248, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7268041237113402, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7474226804123711, 0.575, 'X[2] <= 0.535\nentropy = 1.432\nsamples = 14\nvalue = [0, 0, 2, 7, 5, 0]'),
#  Text(0.7371134020618557, 0.525, 'X[0] <= 9.6\nentropy = 0.764\nsamples = 9\nvalue = [0, 0, 0, 7, 2, 0]'),
#  Text(0.7319587628865979, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.7422680412371134, 0.475, 'X[10] <= 10.85\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.7371134020618557, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7474226804123711, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7577319587628866, 0.525, 'X[8] <= 3.29\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 2, 0, 3, 0]'),
#  Text(0.7525773195876289, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7628865979381443, 0.475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8195876288659794, 0.725, 'X[3] <= 4.1\nentropy = 1.27\nsamples = 60\nvalue = [0, 0, 13, 39, 8, 0]'),
#  Text(0.8092783505154639, 0.675, 'X[2] <= 0.655\nentropy = 1.142\nsamples = 53\nvalue = [0, 0, 8, 38, 7, 0]'),
#  Text(0.8041237113402062, 0.625, 'X[8] <= 3.325\nentropy = 1.064\nsamples = 51\nvalue = [0, 0, 8, 38, 5, 0]'),
#  Text(0.788659793814433, 0.575, 'X[8] <= 3.19\nentropy = 0.602\nsamples = 34\nvalue = [0, 0, 5, 29, 0, 0]'),
#  Text(0.7835051546391752, 0.525, 'X[7] <= 0.997\nentropy = 0.896\nsamples = 16\nvalue = [0, 0, 5, 11, 0, 0]'),
#  Text(0.7731958762886598, 0.475, 'X[1] <= 0.44\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.7680412371134021, 0.425, 'X[8] <= 3.155\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.7628865979381443, 0.375, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.7731958762886598, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7783505154639175, 0.425, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7938144329896907, 0.475, 'X[6] <= 69.0\nentropy = 0.503\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.788659793814433, 0.425, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.7989690721649485, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7938144329896907, 0.525, 'entropy = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]'),
#  Text(0.8195876288659794, 0.575, 'X[4] <= 0.067\nentropy = 1.447\nsamples = 17\nvalue = [0, 0, 3, 9, 5, 0]'),
#  Text(0.8144329896907216, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8247422680412371, 0.525, 'X[9] <= 0.7\nentropy = 1.287\nsamples = 14\nvalue = [0, 0, 3, 9, 2, 0]'),
#  Text(0.8144329896907216, 0.475, 'X[4] <= 0.079\nentropy = 1.0\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.8092783505154639, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8195876288659794, 0.425, 'X[3] <= 3.25\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.8144329896907216, 0.375, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8247422680412371, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8350515463917526, 0.475, 'X[7] <= 0.998\nentropy = 0.811\nsamples = 8\nvalue = [0, 0, 0, 6, 2, 0]'),
#  Text(0.8298969072164949, 0.425, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.8402061855670103, 0.425, 'X[0] <= 8.4\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.8350515463917526, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.845360824742268, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8144329896907216, 0.625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8298969072164949, 0.675, 'X[9] <= 0.68\nentropy = 1.149\nsamples = 7\nvalue = [0, 0, 5, 1, 1, 0]'),
#  Text(0.8247422680412371, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8350515463917526, 0.625, 'X[2] <= 0.34\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 5, 0, 1, 0]'),
#  Text(0.8298969072164949, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8402061855670103, 0.575, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.9555412371134021, 0.825, 'X[3] <= 4.75\nentropy = 1.556\nsamples = 88\nvalue = [0, 0, 5, 32, 44, 7]'),
#  Text(0.9265463917525774, 0.775, 'X[5] <= 18.5\nentropy = 1.445\nsamples = 82\nvalue = [0, 0, 3, 32, 42, 5]'),
#  Text(0.8917525773195877, 0.725, 'X[9] <= 0.695\nentropy = 1.346\nsamples = 57\nvalue = [0, 0, 3, 17, 35, 2]'),
#  Text(0.865979381443299, 0.675, 'X[6] <= 24.5\nentropy = 1.418\nsamples = 21\nvalue = [0, 0, 3, 11, 7, 0]'),
#  Text(0.8556701030927835, 0.625, 'X[2] <= 0.565\nentropy = 0.881\nsamples = 10\nvalue = [0, 0, 0, 3, 7, 0]'),
#  Text(0.8505154639175257, 0.575, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.8608247422680413, 0.575, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8762886597938144, 0.625, 'X[8] <= 3.34\nentropy = 0.845\nsamples = 11\nvalue = [0, 0, 3, 8, 0, 0]'),
#  Text(0.8711340206185567, 0.575, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8814432989690721, 0.575, 'X[7] <= 0.994\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 3, 4, 0, 0]'),
#  Text(0.8762886597938144, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8865979381443299, 0.525, 'X[4] <= 0.064\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.8814432989690721, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8917525773195877, 0.475, 'X[4] <= 0.078\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.8865979381443299, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8969072164948454, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9175257731958762, 0.675, 'X[5] <= 9.5\nentropy = 0.944\nsamples = 36\nvalue = [0, 0, 0, 6, 28, 2]'),
#  Text(0.9123711340206185, 0.625, 'X[8] <= 3.205\nentropy = 1.449\nsamples = 14\nvalue = [0, 0, 0, 6, 6, 2]'),
#  Text(0.9020618556701031, 0.575, 'X[2] <= 0.635\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2]'),
#  Text(0.8969072164948454, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9072164948453608, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9226804123711341, 0.575, 'X[2] <= 0.41\nentropy = 0.994\nsamples = 11\nvalue = [0, 0, 0, 6, 5, 0]'),
#  Text(0.9175257731958762, 0.525, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.9278350515463918, 0.525, 'X[6] <= 29.0\nentropy = 0.592\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.9226804123711341, 0.475, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.9329896907216495, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9226804123711341, 0.625, 'entropy = 0.0\nsamples = 22\nvalue = [0, 0, 0, 0, 22, 0]'),
#  Text(0.961340206185567, 0.725, 'X[7] <= 0.995\nentropy = 1.323\nsamples = 25\nvalue = [0, 0, 0, 15, 7, 3]'),
#  Text(0.9484536082474226, 0.675, 'X[5] <= 35.5\nentropy = 1.189\nsamples = 12\nvalue = [0, 0, 0, 8, 1, 3]'),
#  Text(0.9381443298969072, 0.625, 'X[1] <= 0.41\nentropy = 0.722\nsamples = 10\nvalue = [0, 0, 0, 8, 0, 2]'),
#  Text(0.9329896907216495, 0.575, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.9432989690721649, 0.575, 'X[1] <= 0.52\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 2, 0, 2]'),
#  Text(0.9381443298969072, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9484536082474226, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9587628865979382, 0.625, 'X[3] <= 1.95\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.9536082474226805, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9639175257731959, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9742268041237113, 0.675, 'X[7] <= 0.995\nentropy = 0.996\nsamples = 13\nvalue = [0, 0, 0, 7, 6, 0]'),
#  Text(0.9690721649484536, 0.625, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.979381443298969, 0.625, 'X[8] <= 3.365\nentropy = 0.881\nsamples = 10\nvalue = [0, 0, 0, 7, 3, 0]'),
#  Text(0.9742268041237113, 0.575, 'X[7] <= 0.997\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 0, 2, 3, 0]'),
#  Text(0.9690721649484536, 0.525, 'X[3] <= 2.45\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.9639175257731959, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9742268041237113, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.979381443298969, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9845360824742269, 0.575, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9845360824742269, 0.775, 'X[5] <= 14.0\nentropy = 1.585\nsamples = 6\nvalue = [0, 0, 2, 0, 2, 2]'),
#  Text(0.979381443298969, 0.725, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9896907216494846, 0.725, 'X[10] <= 12.8\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.9845360824742269, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9948453608247423, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]')]

# %%
dt1 = df.head(30)
dt1.head()

x1 = dt1.drop(columns=['quality'])
y1 = dt1['quality']

# %%
x1.head()
y1.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
mod_dt1 = DecisionTreeClassifier(criterion='entropy')
mod_dt1.fit(x1, y1)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# Visualizing..

plt.figure(figsize=(25, 25))
tree.plot_tree(mod_dt1, filled=True, class_names=[str(i) for i in set(y1)],
              feature_names=x1.columns)

# saving the decision tree as img
plt.savefig('decision_tree_entropy')

# %%
x1.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
print(x1['volatile acidity'].median())
print(x1['volatile acidity'].mean())

## As we can see threshold the decision tree is trying to use to divide the branches is neither
# the median nor mean

## in the live class sir told that there's some custom mechanism built in each algorithm to 
# compute the thresholds.
# Out:
# 0.58
# 0.5373333333333333

# %%
mod_dt1.score(x1, y1)

## shamelessly overfitted..
# Out:
# 1.0

# %%
mod_dt1.score(x_test, y_test)
# Out:
# 0.38125

# %%
mod_dt1.score(x1_test, y1_test)
# Out:
# 0.40441176470588236

# %% [markdown]
# ## It's better to discard the further branches from a certain step in a decision tree if the `concrete decision` can be made from that ceratin step itself consequently reducing the complexity and not to spend computational power unnecessarily.
# ### Here comes the concept of `pre-pruning` and `post-pruning`

# %%
# Compute the pruning path during Minimal Cost-Complexity Pruning.
path = mod_dt1.cost_complexity_pruning_path(x1, y1)
path

## kind of `thresh probab` to discard a certain branch if its cost complexity is higher than the 
# `thresh`
# Out:
# {'ccp_alphas': array([0.        , 0.06666667, 0.09182958, 0.10150722, 0.10817042,
#         0.13333333, 0.19562766, 0.27679444, 0.31285482]),
#  'impurities': array([0.        , 0.06666667, 0.15849625, 0.26000347, 0.36817388,
#         0.50150722, 0.69713487, 0.97392931, 1.28678413])}

# %% [markdown]
# ### ccp_alphas:
#
# **Complexity parameter used for `Minimal Cost-Complexity Pruning`. The
# subtree with the largest cost complexity that is smaller than
# ``ccp_alpha`` will be chosen. By default, no pruning is performed.**

# %% [markdown]
# - ### `pre-pruning`

# %%
alphas = path['ccp_alphas']
alphas
# Out:
# array([0.        , 0.06666667, 0.09182958, 0.10150722, 0.10817042,
#        0.13333333, 0.19562766, 0.27679444, 0.31285482])

# %% [markdown]
# ### building model for each ccp_alpha:

# %%
models = []
for ccp in alphas:
    model = DecisionTreeClassifier(ccp_alpha=ccp)
    model.fit(x1, y1)
    models.append(model)

# %%
models
# Out:
# [DecisionTreeClassifier(),
#  DecisionTreeClassifier(ccp_alpha=0.06666666666666667),
#  DecisionTreeClassifier(ccp_alpha=0.09182958340544896),
#  DecisionTreeClassifier(ccp_alpha=0.10150721594810842),
#  DecisionTreeClassifier(ccp_alpha=0.10817041659455104),
#  DecisionTreeClassifier(ccp_alpha=0.13333333333333336),
#  DecisionTreeClassifier(ccp_alpha=0.1956276577222191),
#  DecisionTreeClassifier(ccp_alpha=0.27679443603470466),
#  DecisionTreeClassifier(ccp_alpha=0.3128548240716781)]

# %%
train_scores = [i.score(x1, y1) for i in models]
train_scores
# Out:
# [1.0, 0.8333333333333334, 0.8, 0.8, 0.8, 0.7, 0.7, 0.7, 0.7]

# %%
test_scores = [i.score(x_test, y_test) for i in models]
test_scores
# Out:
# [0.43125,
#  0.4125,
#  0.446875,
#  0.446875,
#  0.4125,
#  0.43125,
#  0.43125,
#  0.43125,
#  0.43125]

# %% [markdown]
# ## Why do `decision trees` overfit so much?
#
# **Decision trees are prone to overfitting, especially when a tree is particularly deep. This is due to the amount of specificity we look at leading to smaller sample of events that meet the previous assumptions. This small sample could lead to unsound conclusions.**
#
# ***In layman terms, the decision tree model becomes too complex, and apparently loses its edge on `generalization`.***

# %%
fig, ax = plt.subplots()
ax.set_xlabel("ccp_alpha")
ax.set_ylabel("accuracy")

ax.plot(alphas, train_scores, marker='o', label='train', drawstyle='steps-post')
ax.plot(alphas, test_scores, marker='o', label='test', drawstyle='steps-post')

ax.legend()
plt.show()

# %%
### Manual Hyperparameter tuning:

# %%
### let's check the same for substantail amount of datset (i.e for our foremost model `mod`)

path = mod.cost_complexity_pruning_path(x_train, y_train)
alphas = path['ccp_alphas']

models = []
for ccp in alphas:
    model = DecisionTreeClassifier(ccp_alpha=ccp)
    model.fit(x_train, y_train)
    models.append(model)

models
# Out:
# [DecisionTreeClassifier(),
#  DecisionTreeClassifier(ccp_alpha=0.0006701664246621245),
#  DecisionTreeClassifier(ccp_alpha=0.0007107825716113442),
#  DecisionTreeClassifier(ccp_alpha=0.0007167057597081053),
#  DecisionTreeClassifier(ccp_alpha=0.0007217176880976721),
#  DecisionTreeClassifier(ccp_alpha=0.0007217176880976721),
#  DecisionTreeClassifier(ccp_alpha=0.0007260136267173017),
#  DecisionTreeClassifier(ccp_alpha=0.0007260136267173017),
#  DecisionTreeClassifier(ccp_alpha=0.0007260136267173017),
#  DecisionTreeClassifier(ccp_alpha=0.0007285521359016277),
#  DecisionTreeClassifier(ccp_alpha=0.0007297367735209802),
#  DecisionTreeClassifier(ccp_alpha=0.000744629360735694),
#  DecisionTreeClassifier(ccp_alpha=0.0007505863956215791),
#  DecisionTreeClassifier(ccp_alpha=0.0007539372277448899),
#  DecisionTreeClassifier(ccp_alpha=0.0007574276778733386),
#  DecisionTreeClassifier(ccp_alpha=0.000758864922043876),
#  DecisionTreeClassifier(ccp_alpha=0.0007627910524609549),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0007818608287724785),
#  DecisionTreeClassifier(ccp_alpha=0.0008935552328828326),
#  DecisionTreeClassifier(ccp_alpha=0.0009382329945269741),
#  DecisionTreeClassifier(ccp_alpha=0.0009382329945269741),
#  DecisionTreeClassifier(ccp_alpha=0.000990357049778473),
#  DecisionTreeClassifier(ccp_alpha=0.000990357049778473),
#  DecisionTreeClassifier(ccp_alpha=0.0009990443923203894),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0010424811050299713),
#  DecisionTreeClassifier(ccp_alpha=0.0011169440411035406),
#  DecisionTreeClassifier(ccp_alpha=0.0011372521145781504),
#  DecisionTreeClassifier(ccp_alpha=0.0011391628204158156),
#  DecisionTreeClassifier(ccp_alpha=0.001149098490771674),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587176),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587176),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587176),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587176),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587176),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.0011727912431587178),
#  DecisionTreeClassifier(ccp_alpha=0.00119140697717711),
#  DecisionTreeClassifier(ccp_alpha=0.0011932835632676737),
#  DecisionTreeClassifier(ccp_alpha=0.0012162279558682997),
#  DecisionTreeClassifier(ccp_alpha=0.00122644835885879),
#  DecisionTreeClassifier(ccp_alpha=0.0012286384452138948),
#  DecisionTreeClassifier(ccp_alpha=0.0012509773260359653),
#  DecisionTreeClassifier(ccp_alpha=0.0012509773260359653),
#  DecisionTreeClassifier(ccp_alpha=0.0012509773260359653),
#  DecisionTreeClassifier(ccp_alpha=0.0012584236196433226),
#  DecisionTreeClassifier(ccp_alpha=0.0012584236196433226),
#  DecisionTreeClassifier(ccp_alpha=0.0012865914995335958),
#  DecisionTreeClassifier(ccp_alpha=0.001286827354987223),
#  DecisionTreeClassifier(ccp_alpha=0.0012965858743810266),
#  DecisionTreeClassifier(ccp_alpha=0.0013010411419494606),
#  DecisionTreeClassifier(ccp_alpha=0.0013031013812874641),
#  DecisionTreeClassifier(ccp_alpha=0.0013031013812874641),
#  DecisionTreeClassifier(ccp_alpha=0.0013031013812874641),
#  DecisionTreeClassifier(ccp_alpha=0.0013031013812874641),
#  DecisionTreeClassifier(ccp_alpha=0.0013031013812874641),
#  DecisionTreeClassifier(ccp_alpha=0.0013155118706330586),
#  DecisionTreeClassifier(ccp_alpha=0.00133271732177127),
#  DecisionTreeClassifier(ccp_alpha=0.0013354814762164254),
#  DecisionTreeClassifier(ccp_alpha=0.001336816351060513),
#  DecisionTreeClassifier(ccp_alpha=0.001340332849324249),
#  DecisionTreeClassifier(ccp_alpha=0.001340332849324249),
#  DecisionTreeClassifier(ccp_alpha=0.001340332849324249),
#  DecisionTreeClassifier(ccp_alpha=0.0013527433386698435),
#  DecisionTreeClassifier(ccp_alpha=0.0013589485833426411),
#  DecisionTreeClassifier(ccp_alpha=0.0013682564503518374),
#  DecisionTreeClassifier(ccp_alpha=0.0013682564503518374),
#  DecisionTreeClassifier(ccp_alpha=0.0013682564503518376),
#  DecisionTreeClassifier(ccp_alpha=0.001374771957258274),
#  DecisionTreeClassifier(ccp_alpha=0.0013981925631651984),
#  DecisionTreeClassifier(ccp_alpha=0.0014073494917904614),
#  DecisionTreeClassifier(ccp_alpha=0.0014073494917904614),
#  DecisionTreeClassifier(ccp_alpha=0.0014073494917904617),
#  DecisionTreeClassifier(ccp_alpha=0.0014073494917904617),
#  DecisionTreeClassifier(ccp_alpha=0.0014249498221351226),
#  DecisionTreeClassifier(ccp_alpha=0.001436192528461641),
#  DecisionTreeClassifier(ccp_alpha=0.0014402699477387764),
#  DecisionTreeClassifier(ccp_alpha=0.0014452578956097323),
#  DecisionTreeClassifier(ccp_alpha=0.001445841101822337),
#  DecisionTreeClassifier(ccp_alpha=0.0014520272534346034),
#  DecisionTreeClassifier(ccp_alpha=0.0014582324981074004),
#  DecisionTreeClassifier(ccp_alpha=0.00145947354704196),
#  DecisionTreeClassifier(ccp_alpha=0.0014594735470419603),
#  DecisionTreeClassifier(ccp_alpha=0.0014698983580922593),
#  DecisionTreeClassifier(ccp_alpha=0.001471738030630548),
#  DecisionTreeClassifier(ccp_alpha=0.001471738030630548),
#  DecisionTreeClassifier(ccp_alpha=0.001472847482270963),
#  DecisionTreeClassifier(ccp_alpha=0.0014926434003838234),
#  DecisionTreeClassifier(ccp_alpha=0.0015078744554897798),
#  DecisionTreeClassifier(ccp_alpha=0.0015190438959008143),
#  DecisionTreeClassifier(ccp_alpha=0.0015190438959008154),
#  DecisionTreeClassifier(ccp_alpha=0.001563721657544957),
#  DecisionTreeClassifier(ccp_alpha=0.001563721657544957),
#  DecisionTreeClassifier(ccp_alpha=0.001563721657544957),
#  DecisionTreeClassifier(ccp_alpha=0.001563721657544957),
#  DecisionTreeClassifier(ccp_alpha=0.0015637216575449574),
#  DecisionTreeClassifier(ccp_alpha=0.0015644129580124856),
#  DecisionTreeClassifier(ccp_alpha=0.0015953684053762237),
#  DecisionTreeClassifier(ccp_alpha=0.001615845712796456),
#  DecisionTreeClassifier(ccp_alpha=0.0016246977609049196),
#  DecisionTreeClassifier(ccp_alpha=0.0016347999147060914),
#  DecisionTreeClassifier(ccp_alpha=0.0016381845936185267),
#  DecisionTreeClassifier(ccp_alpha=0.001675416061655311),
#  DecisionTreeClassifier(ccp_alpha=0.0016772834707104466),
#  DecisionTreeClassifier(ccp_alpha=0.0016810007818608289),
#  DecisionTreeClassifier(ccp_alpha=0.0016940317956737026),
#  DecisionTreeClassifier(ccp_alpha=0.0017147159445830285),
#  DecisionTreeClassifier(ccp_alpha=0.0017170277024023055),
#  DecisionTreeClassifier(ccp_alpha=0.0017200938232994518),
#  DecisionTreeClassifier(ccp_alpha=0.0017302263346664814),
#  DecisionTreeClassifier(ccp_alpha=0.0017591868647380765),
#  DecisionTreeClassifier(ccp_alpha=0.0017731486652518705),
#  DecisionTreeClassifier(ccp_alpha=0.0017952137852795536),
#  DecisionTreeClassifier(ccp_alpha=0.0018183516609637448),
#  DecisionTreeClassifier(ccp_alpha=0.00182434193380245),
#  DecisionTreeClassifier(ccp_alpha=0.0018375857953908522),
#  DecisionTreeClassifier(ccp_alpha=0.0018440858941249875),
#  DecisionTreeClassifier(ccp_alpha=0.0018677786465120315),
#  DecisionTreeClassifier(ccp_alpha=0.0019185156470719637),
#  DecisionTreeClassifier(ccp_alpha=0.0019358922532841782),
#  DecisionTreeClassifier(ccp_alpha=0.001993096059041974),
#  DecisionTreeClassifier(ccp_alpha=0.002019807140995569),
#  DecisionTreeClassifier(ccp_alpha=0.002029598010833352),
#  DecisionTreeClassifier(ccp_alpha=0.0020621579358874125),
#  DecisionTreeClassifier(ccp_alpha=0.0020827154835404843),
#  DecisionTreeClassifier(ccp_alpha=0.0021106813162695623),
#  DecisionTreeClassifier(ccp_alpha=0.002147014656787917),
#  DecisionTreeClassifier(ccp_alpha=0.002171835635479107),
#  DecisionTreeClassifier(ccp_alpha=0.002178040880151904),
#  DecisionTreeClassifier(ccp_alpha=0.002195586744399125),
#  DecisionTreeClassifier(ccp_alpha=0.00228823479190819),
#  DecisionTreeClassifier(ccp_alpha=0.0023195204586916856),
#  DecisionTreeClassifier(ccp_alpha=0.0023455824863174357),
#  DecisionTreeClassifier(ccp_alpha=0.002363414399956106),
#  DecisionTreeClassifier(ccp_alpha=0.0023716445139431853),
#  DecisionTreeClassifier(ccp_alpha=0.0023887796142906155),
#  DecisionTreeClassifier(ccp_alpha=0.002391026778185864),
#  DecisionTreeClassifier(ccp_alpha=0.002397869939861255),
#  DecisionTreeClassifier(ccp_alpha=0.002439164284355838),
#  DecisionTreeClassifier(ccp_alpha=0.0024458201003713397),
#  DecisionTreeClassifier(ccp_alpha=0.0024479690234185947),
#  DecisionTreeClassifier(ccp_alpha=0.0024883990572525288),
#  DecisionTreeClassifier(ccp_alpha=0.0025258448440621997),
#  DecisionTreeClassifier(ccp_alpha=0.0026722040013674097),
#  DecisionTreeClassifier(ccp_alpha=0.002701763530536009),
#  DecisionTreeClassifier(ccp_alpha=0.002727966586449776),
#  DecisionTreeClassifier(ccp_alpha=0.002733304507151268),
#  DecisionTreeClassifier(ccp_alpha=0.0029579549654976216),
#  DecisionTreeClassifier(ccp_alpha=0.002970536151700863),
#  DecisionTreeClassifier(ccp_alpha=0.0030288608627664264),
#  DecisionTreeClassifier(ccp_alpha=0.003069380543346642),
#  DecisionTreeClassifier(ccp_alpha=0.0031357442765431627),
#  DecisionTreeClassifier(ccp_alpha=0.003394922019669973),
#  DecisionTreeClassifier(ccp_alpha=0.0034253246496112402),
#  DecisionTreeClassifier(ccp_alpha=0.0034404076188173463),
#  DecisionTreeClassifier(ccp_alpha=0.0036985083321835386),
#  DecisionTreeClassifier(ccp_alpha=0.003860226299632086),
#  DecisionTreeClassifier(ccp_alpha=0.003861094543353087),
#  DecisionTreeClassifier(ccp_alpha=0.003989789817412492),
#  DecisionTreeClassifier(ccp_alpha=0.003991304182001942),
#  DecisionTreeClassifier(ccp_alpha=0.004251833649800809),
#  DecisionTreeClassifier(ccp_alpha=0.004598514797699349),
#  DecisionTreeClassifier(ccp_alpha=0.004846715431570878),
#  DecisionTreeClassifier(ccp_alpha=0.00490356420260897),
#  DecisionTreeClassifier(ccp_alpha=0.006055491434693944),
#  DecisionTreeClassifier(ccp_alpha=0.006863204812647766),
#  DecisionTreeClassifier(ccp_alpha=0.008007180159283894),
#  DecisionTreeClassifier(ccp_alpha=0.012035334011119114),
#  DecisionTreeClassifier(ccp_alpha=0.0127775572359283),
#  DecisionTreeClassifier(ccp_alpha=0.014588863105259198),
#  DecisionTreeClassifier(ccp_alpha=0.05739602228611651)]

# %%
train_scores = [i.score(x_train, y_train) for i in models]
train_scores
# Out:
# [1.0,
#  0.9992181391712275,
#  0.9984362783424551,
#  0.9976544175136826,
#  0.9960906958561376,
#  0.9960906958561376,
#  0.9937451133698202,
#  0.9937451133698202,
#  0.9937451133698202,
#  0.9921813917122753,
#  0.9913995308835027,
#  0.9906176700547302,
#  0.9898358092259578,
#  0.9890539483971853,
#  0.9882720875684128,
#  0.9874902267396404,
#  0.9867083659108679,
#  0.9679437060203284,
#  0.9695074276778733,
#  0.9679437060203284,
#  0.9695074276778733,
#  0.9687255668491008,
#  0.9687255668491008,
#  0.9695074276778733,
#  0.9695074276778733,
#  0.9695074276778733,
#  0.9702892885066459,
#  0.9679437060203284,
#  0.9702892885066459,
#  0.9687255668491008,
#  0.9687255668491008,
#  0.9687255668491008,
#  0.9687255668491008,
#  0.9695074276778733,
#  0.9702892885066459,
#  0.9687255668491008,
#  0.9663799843627834,
#  0.9632525410476935,
#  0.9640344018764659,
#  0.9616888193901486,
#  0.9609069585613761,
#  0.9609069585613761,
#  0.9499609069585614,
#  0.9507427677873339,
#  0.9483971853010165,
#  0.9499609069585614,
#  0.9499609069585614,
#  0.9483971853010165,
#  0.9491790461297889,
#  0.9507427677873339,
#  0.9507427677873339,
#  0.9483971853010165,
#  0.9499609069585614,
#  0.9507427677873339,
#  0.9499609069585614,
#  0.9507427677873339,
#  0.9483971853010165,
#  0.946051602814699,
#  0.9437060203283816,
#  0.9429241594996091,
#  0.9413604378420641,
#  0.9382329945269742,
#  0.9382329945269742,
#  0.9413604378420641,
#  0.9421422986708365,
#  0.9311962470680218,
#  0.9304143862392494,
#  0.9311962470680218,
#  0.9351055512118843,
#  0.9343236903831118,
#  0.9319781078967944,
#  0.9343236903831118,
#  0.9319781078967944,
#  0.9319781078967944,
#  0.9311962470680218,
#  0.9327599687255669,
#  0.928068803752932,
#  0.9296325254104769,
#  0.9257232212666145,
#  0.9233776387802971,
#  0.9272869429241595,
#  0.9225957779515246,
#  0.9241594996090696,
#  0.9241594996090696,
#  0.9202501954652071,
#  0.9147771696637998,
#  0.9155590304925724,
#  0.9124315871774824,
#  0.9061767005473026,
#  0.90852228303362,
#  0.9093041438623924,
#  0.90852228303362,
#  0.90852228303362,
#  0.9077404222048475,
#  0.9007036747458952,
#  0.8991399530883503,
#  0.8928850664581705,
#  0.8921032056293979,
#  0.893666927286943,
#  0.8928850664581705,
#  0.8913213448006255,
#  0.887412040656763,
#  0.887412040656763,
#  0.8866301798279906,
#  0.8850664581704457,
#  0.8835027365129007,
#  0.8827208756841283,
#  0.8858483189992181,
#  0.8788115715402658,
#  0.8780297107114934,
#  0.8780297107114934,
#  0.8835027365129007,
#  0.8749022673964034,
#  0.8788115715402658,
#  0.8788115715402658,
#  0.8780297107114934,
#  0.872556684910086,
#  0.8694292415949961,
#  0.8702111024237685,
#  0.8686473807662236,
#  0.8663017982799062,
#  0.8655199374511336,
#  0.8678655199374511,
#  0.8608287724784989,
#  0.8600469116497264,
#  0.8600469116497264,
#  0.8600469116497264,
#  0.8553557466770915,
#  0.8522283033620016,
#  0.853010164190774,
#  0.853010164190774,
#  0.8522283033620016,
#  0.8498827208756842,
#  0.8522283033620016,
#  0.8491008600469117,
#  0.8475371383893667,
#  0.8436278342455042,
#  0.8412822517591869,
#  0.8405003909304144,
#  0.836591086786552,
#  0.836591086786552,
#  0.835027365129007,
#  0.8334636434714621,
#  0.8311180609851446,
#  0.8303362001563722,
#  0.8295543393275997,
#  0.8209538702111024,
#  0.8193901485535575,
#  0.818608287724785,
#  0.8170445660672401,
#  0.8162627052384676,
#  0.8146989835809226,
#  0.8146989835809226,
#  0.8123534010946052,
#  0.8100078186082877,
#  0.8092259577795152,
#  0.8037529319781079,
#  0.8021892103205629,
#  0.7998436278342455,
#  0.7998436278342455,
#  0.7967161845191556,
#  0.7943706020328382,
#  0.7928068803752932,
#  0.7873338545738858,
#  0.7849882720875684,
#  0.7826426896012509,
#  0.7787333854573886,
#  0.7724784988272088,
#  0.7709147771696638,
#  0.7693510555121188,
#  0.763096168881939,
#  0.7615324472243941,
#  0.7615324472243941,
#  0.7615324472243941,
#  0.7584050039093041,
#  0.7544956997654417,
#  0.7458952306489445,
#  0.7443315089913995,
#  0.7365129007036747,
#  0.7310398749022674,
#  0.7279124315871774,
#  0.7200938232994527,
#  0.7154026583268178,
#  0.7075840500390931,
#  0.7021110242376857,
#  0.6958561376075059,
#  0.6935105551211884,
#  0.6872556684910086,
#  0.6849100860046912,
#  0.6810007818608288,
#  0.6724003127443315,
#  0.6622361219702892,
#  0.6505082095387021,
#  0.6450351837372947,
#  0.6426896012509773,
#  0.6426896012509773,
#  0.6395621579358874,
#  0.6348709929632526,
#  0.6293979671618452,
#  0.6247068021892104,
#  0.619233776387803,
#  0.6012509773260359,
#  0.6012509773260359,
#  0.5856137607505864,
#  0.5856137607505864,
#  0.5598123534010946,
#  0.5598123534010946,
#  0.4245504300234558]

# %%
test_scores = [i.score(x_test, y_test) for i in models]
test_scores
# Out:
# [0.6375,
#  0.63125,
#  0.6375,
#  0.634375,
#  0.634375,
#  0.625,
#  0.6375,
#  0.634375,
#  0.625,
#  0.63125,
#  0.64375,
#  0.628125,
#  0.6375,
#  0.640625,
#  0.628125,
#  0.628125,
#  0.640625,
#  0.628125,
#  0.6125,
#  0.603125,
#  0.615625,
#  0.61875,
#  0.61875,
#  0.609375,
#  0.621875,
#  0.621875,
#  0.6125,
#  0.60625,
#  0.609375,
#  0.628125,
#  0.625,
#  0.621875,
#  0.6125,
#  0.628125,
#  0.61875,
#  0.615625,
#  0.609375,
#  0.621875,
#  0.6125,
#  0.60625,
#  0.63125,
#  0.609375,
#  0.6125,
#  0.6125,
#  0.61875,
#  0.6,
#  0.60625,
#  0.615625,
#  0.603125,
#  0.6125,
#  0.60625,
#  0.60625,
#  0.609375,
#  0.60625,
#  0.609375,
#  0.61875,
#  0.60625,
#  0.603125,
#  0.609375,
#  0.603125,
#  0.603125,
#  0.609375,
#  0.603125,
#  0.60625,
#  0.596875,
#  0.6,
#  0.609375,
#  0.60625,
#  0.609375,
#  0.603125,
#  0.609375,
#  0.6,
#  0.60625,
#  0.6,
#  0.60625,
#  0.596875,
#  0.590625,
#  0.6,
#  0.60625,
#  0.6,
#  0.6,
#  0.60625,
#  0.6125,
#  0.6,
#  0.609375,
#  0.596875,
#  0.6125,
#  0.60625,
#  0.596875,
#  0.60625,
#  0.596875,
#  0.603125,
#  0.60625,
#  0.60625,
#  0.6,
#  0.603125,
#  0.6,
#  0.609375,
#  0.609375,
#  0.603125,
#  0.6125,
#  0.596875,
#  0.5875,
#  0.596875,
#  0.6,
#  0.6,
#  0.609375,
#  0.60625,
#  0.6,
#  0.60625,
#  0.603125,
#  0.6125,
#  0.609375,
#  0.6125,
#  0.60625,
#  0.61875,
#  0.609375,
#  0.615625,
#  0.603125,
#  0.6125,
#  0.609375,
#  0.609375,
#  0.60625,
#  0.59375,
#  0.603125,
#  0.590625,
#  0.603125,
#  0.6,
#  0.6,
#  0.596875,
#  0.59375,
#  0.603125,
#  0.603125,
#  0.603125,
#  0.61875,
#  0.609375,
#  0.6125,
#  0.603125,
#  0.603125,
#  0.615625,
#  0.6125,
#  0.61875,
#  0.6125,
#  0.615625,
#  0.615625,
#  0.6125,
#  0.61875,
#  0.61875,
#  0.621875,
#  0.628125,
#  0.628125,
#  0.63125,
#  0.63125,
#  0.621875,
#  0.615625,
#  0.621875,
#  0.615625,
#  0.615625,
#  0.609375,
#  0.6125,
#  0.609375,
#  0.609375,
#  0.6125,
#  0.603125,
#  0.596875,
#  0.596875,
#  0.6,
#  0.603125,
#  0.6,
#  0.603125,
#  0.603125,
#  0.603125,
#  0.603125,
#  0.6,
#  0.6,
#  0.60625,
#  0.60625,
#  0.60625,
#  0.60625,
#  0.6,
#  0.60625,
#  0.6,
#  0.609375,
#  0.609375,
#  0.60625,
#  0.6,
#  0.603125,
#  0.6125,
#  0.615625,
#  0.615625,
#  0.615625,
#  0.60625,
#  0.584375,
#  0.578125,
#  0.553125,
#  0.553125,
#  0.55,
#  0.546875,
#  0.559375,
#  0.553125,
#  0.553125,
#  0.5375,
#  0.5375,
#  0.53125,
#  0.53125,
#  0.565625,
#  0.565625,
#  0.43125]

# %%
# let's visualize..

fig, ax = plt.subplots()
ax.set_xlabel("ccp_alpha")
ax.set_ylabel("accuracy")

ax.plot(alphas, train_scores, marker='o', label='train', drawstyle='steps-post')
ax.plot(alphas, test_scores, marker='o', label='test', drawstyle='steps-post')

ax.legend()
plt.show()

# %% [markdown]
# ## We can very well deal with the less accuracy whatsoever but the main  idea is to have a `robust model` i.e. to reduce the difference between `test accuracy` and `train accuracy` as much as possible.
#
# ### The reason for all this being so apparent that I could almost laugh i.e. if it is for the smaller dataset our model won't be able to generalize well.

# %% [markdown]
# ### Possible solutions if my model overfits:
#
# - ### Increase the dataset size so that it would be able to generalize well.
# - ### Hyperparameter tuning using cost_complexity_pruning and other relevant parameters.

# %%
## Let's now build the model with suitable `ccp_alpha` val..
# using alpha = 0.015 as interpreted from the above graph

tree_mod = DecisionTreeClassifier(ccp_alpha=0.015)
tree_mod.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.015)

# %%
print(tree_mod.score(x_train, y_train))
print(tree_mod.score(x_test, y_test))

# hence, we successed in removing the `overfitting`
# Out:
# 0.5598123534010946
# 0.565625

# %%
plt.figure(figsize=(10, 10))
tree.plot_tree(tree_mod, filled=True)
# Out:
# [Text(0.5, 0.75, 'X[10] <= 10.25\ngini = 0.641\nsamples = 1279\nvalue = [9, 43, 543, 516, 153, 15]'),
#  Text(0.25, 0.25, 'gini = 0.528\nsamples = 688\nvalue = [6, 25, 418, 218, 20, 1]'),
#  Text(0.75, 0.25, 'gini = 0.649\nsamples = 591\nvalue = [3, 18, 125, 298, 133, 14]')]

# %%
### If we keep doing this way manually like we've been doing up till now, then we'll have to 
# create 100s of models because ccp alpha is not the only hyperparameter to be tuned; there still 
# are many hyperparameteres which also require tuning and that too simutaneously.

# --> So for that we have GridSearchCV and RandomSearchCV

# %% [markdown]
# - ### GridSearchCV

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier()

# %%
grid_param = {"criterion": ['gini', 'entropy'],
             "splitter": ['best', 'random'],
             "max_depth": range(2, 40, 1),
             "min_samples_split": range(2, 10, 1),
             "min_samples_leaf": range(1, 10, 1)
             }

# %%
# this's gonna be compute heavy operation
grid_cv = GridSearchCV(estimator=tree_mod, param_grid=grid_param, cv=5, n_jobs=-1)
grid_cv
# cv: 5 horizontal splits outta which 1 is for testing.
# n_jobs: no. of cores of processore to be executed. -1 for to involve all.
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(ccp_alpha=0.015), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 40),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
grid_cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(ccp_alpha=0.015), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 40),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
### Now, we are to find the best possible params
grid_cv.best_params_

# now, the idea is to build the model using these `best parameters`.
# Out:
# {'criterion': 'entropy',
#  'max_depth': 39,
#  'min_samples_leaf': 5,
#  'min_samples_split': 5,
#  'splitter': 'random'}

# %%
best_model = DecisionTreeClassifier(criterion='entropy', max_depth=31, min_samples_leaf=4, 
                                    min_samples_split=9, splitter='random', ccp_alpha=0.015)
best_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.015, criterion='entropy', max_depth=31,
#                        min_samples_leaf=4, min_samples_split=9,
#                        splitter='random')

# %%
print("training_score: ", best_model.score(x_train, y_train)*100)
print("test_score: ", best_model.score(x_test, y_test)*100)

### --> Demonstrates the fact that even after the so-called `hyperparameter tuning`, there ain't no 
# gurantee that we won't get any overfitted model.
# Out:
# training_score:  55.98123534010946
# test_score:  56.56250000000001

# %% [markdown]
# ### Thus `hyperparameter tuning` isn't a univeral resolution for an over-fitted model.

# %% [markdown]
# - ### RandomizedSearchCV

# %%
# RandimizedSearchCV: Randomized search on hyper parameters.

random_params = {"criterion": ['gini', 'entropy'],
             "splitter": ['best', 'random'],
             "max_depth": range(2, 40, 1),
             "min_samples_split": range(2, 10, 1),
             "min_samples_leaf": range(1, 10, 1)
             }

random_cv = RandomizedSearchCV(tree_mod, random_params, cv=5, n_jobs=-1)
random_cv
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(ccp_alpha=0.015),
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(2, 40),
#                                         'min_samples_leaf': range(1, 10),
#                                         'min_samples_split': range(2, 10),
#                                         'splitter': ['best', 'random']})

# %%
random_cv.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(ccp_alpha=0.015),
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(2, 40),
#                                         'min_samples_leaf': range(1, 10),
#                                         'min_samples_split': range(2, 10),
#                                         'splitter': ['best', 'random']})

# %%
random_cv.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 8,
#  'min_samples_leaf': 1,
#  'max_depth': 21,
#  'criterion': 'entropy'}

# %%
r_mod = DecisionTreeClassifier(ccp_alpha=0.015, criterion= 'entropy',
                                        max_depth= 17,
                                        min_samples_leaf=1,
                                        min_samples_split=9,
                                        splitter='random')
r_mod
# Out:
# DecisionTreeClassifier(ccp_alpha=0.015, criterion='entropy', max_depth=17,
#                        min_samples_split=9, splitter='random')

# %%
r_mod.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.015, criterion='entropy', max_depth=17,
#                        min_samples_split=9, splitter='random')

# %%
print("training score:", r_mod.score(x_train, y_train))
print("test scores:", r_mod.score(x_test, y_test))
# Out:
# training score: 0.5699765441751369
# test scores: 0.54375

# %%
pred = r_mod.predict(x_train)
pred
# Out:
# array([5, 6, 6, ..., 5, 5, 5], dtype=int64)

# %%
confusion_matrix(y_train, pred)
# Out:
# array([[  0,   0,   9,   0,   0,   0],
#        [  0,   0,  35,   8,   0,   0],
#        [  0,   0, 481,  62,   0,   0],
#        [  0,   0, 279, 224,  13,   0],
#        [  0,   0,  20, 109,  24,   0],
#        [  0,   0,   0,  12,   3,   0]], dtype=int64)
